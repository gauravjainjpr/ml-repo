# %%
# import libraries

import sklearn

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import datetime

# %%
df = pd.read_csv('datasets/auto-mpg.csv')

df.sample(10)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 281  19.8          6         200.0         85    2990          18.2
# 349  34.1          4          91.0         68    1985          16.0
# 339  26.6          4         151.0         84    2635          16.4
# 92   13.0          8         351.0        158    4363          13.0
# 104  12.0          8         400.0        167    4906          12.5
# 376  37.0          4          91.0         68    2025          18.2
# 184  25.0          4         140.0         92    2572          14.9
# 38   14.0          8         350.0        165    4209          12.0
# 329  44.6          4          91.0         67    1850          13.8
# 54   35.0          4          72.0         69    1613          18.0
#
#      model year  origin             car name
# 281          79       1     mercury zephyr 6
# 349          81       3          mazda glc 4
# 339          81       1        buick skylark
# 92           73       1             ford ltd
# 104          73       1         ford country
# 376          82       3   mazda glc custom l
# 184          76       1             capri ii
# 38           71       1     chevrolet impala
# 329          80       3  honda civic 1500 gl
# 54           71       3          datsun 1200

# %%
df = df.replace('?', np.nan)
df = df.dropna()

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.drop(['origin', 'car name'], axis=1, inplace=True)
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70

# %%
df['model year'] = '19' + df['model year'].astype(str)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration model year
# 0  18.0          8         307.0        130    3504          12.0       1970
# 1  15.0          8         350.0        165    3693          11.5       1970
# 2  18.0          8         318.0        150    3436          11.0       1970
# 3  16.0          8         304.0        150    3433          12.0       1970
# 4  17.0          8         302.0        140    3449          10.5       1970

# %%
df['age'] = datetime.datetime.now().year - pd.to_numeric(df['model year'])

# %%
df.drop('model year', axis=1, inplace=True)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  age
# 0  18.0          8         307.0        130    3504          12.0   53
# 1  15.0          8         350.0        165    3693          11.5   53
# 2  18.0          8         318.0        150    3436          11.0   53
# 3  16.0          8         304.0        150    3433          12.0   53
# 4  17.0          8         302.0        140    3449          10.5   53

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# age               int64
# dtype: object

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 0  18.0          8         307.0         130    3504          12.0   53
# 1  15.0          8         350.0         165    3693          11.5   53
# 2  18.0          8         318.0         150    3436          11.0   53
# 3  16.0          8         304.0         150    3433          12.0   53
# 4  17.0          8         302.0         140    3449          10.5   53

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration         age
# count    392.000000  392.000000
# mean      15.541327   47.020408
# std        2.758864    3.683737
# min        8.000000   41.000000
# 25%       13.775000   44.000000
# 50%       15.500000   47.000000
# 75%       17.025000   50.000000
# max       24.800000   53.000000

# %%
plt.figure(figsize = (12,10))

plt.scatter(df['age'], df['mpg'])

plt.xlabel('Age')
plt.ylabel('Miles per Gallon')
# Out:
# Text(0, 0.5, 'Miles per Gallon')

# %%
plt.figure(figsize = (12,10))

plt.scatter(df['acceleration'], df['mpg'])

plt.xlabel('Acceleration')
plt.ylabel('Miles per Gallon')
# Out:
# Text(0, 0.5, 'Miles per Gallon')

# %%
plt.figure(figsize = (12,10))

plt.scatter(df['weight'], df['mpg'])

plt.xlabel('Weight')
plt.ylabel('Miles per Gallon')
# Out:
# Text(0, 0.5, 'Miles per Gallon')

# %%
plt.figure(figsize = (12,10))

plt.scatter(df['displacement'], df['mpg'])

plt.xlabel('Displacement')
plt.ylabel('Miles per Gallon')
# Out:
# Text(0, 0.5, 'Miles per Gallon')

# %%
plt.figure(figsize = (12,10))

plt.scatter(df['cylinders'], df['mpg'])

plt.xlabel('Cylinders')
plt.ylabel('Miles per Gallon')
# Out:
# Text(0, 0.5, 'Miles per Gallon')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 0  18.0          8         307.0         130    3504          12.0   53
# 1  15.0          8         350.0         165    3693          11.5   53
# 2  18.0          8         318.0         150    3436          11.0   53
# 3  16.0          8         304.0         150    3433          12.0   53
# 4  17.0          8         302.0         140    3449          10.5   53

# %%
df_corr = df.iloc[:,0:7].corr()
df_corr
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# age          -0.580541   0.345647      0.369855    0.416361  0.309120
#
#               acceleration       age
# mpg               0.423329 -0.580541
# cylinders        -0.504683  0.345647
# displacement     -0.543800  0.369855
# horsepower       -0.689196  0.416361
# weight           -0.416839  0.309120
# acceleration      1.000000 -0.290316
# age              -0.290316  1.000000

# %%
fig, ax = plt.subplots(figsize = (10, 8))
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
df = df.sample(frac=1).reset_index(drop=True)

df.to_csv('datasets/auto-mpg-processed.csv', index=False)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 0  24.5          4          98.0          60    2164          22.1   47
# 1  35.0          4          72.0          69    1613          18.0   52
# 2  28.4          4         151.0          90    2670          16.0   44
# 3  19.0          6         225.0         100    3630          17.7   46
# 4  14.0          8         454.0         220    4354           9.0   53

# %% [markdown]
# ## Simple Linear Regression (with one X variable)

# %%
from sklearn.model_selection import train_test_split

X = df[['horsepower']]
Y = df['mpg']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
X.columns
# Out:
# Index(['horsepower'], dtype='object')

# %%
x_train.sample(5)
# Out:
#      horsepower
# 326         170
# 232         108
# 4           220
# 259         150
# 49           90

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression().fit(x_train, y_train)

# %%
print('Training Score: ', linear_model.score(x_train, y_train))
# Out:
# Training Score:  0.627047294118594

# %%
y_pred = linear_model.predict(x_test)

# %%
from sklearn.metrics import r2_score

print('Testing Score: ', r2_score(y_test, y_pred))
# Out:
# Testing Score:  0.42134457396254543

# %%
fig, ax = plt.subplots(figsize = (12, 10))

plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')

plt.xlabel('Horsepower')
plt.ylabel('Mpg')
plt.show()

# %%
X = df[['age']]
Y = df['mpg']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

linear_model = LinearRegression().fit(x_train, y_train)
print('Training Score: ', linear_model.score(x_train, y_train))

y_pred = linear_model.predict(x_test)
print('Testing Score: ', r2_score(y_test, y_pred))
# Out:
# Training Score:  0.36770184211179013
# Testing Score:  0.17979425399544458

# %%
fig, ax = plt.subplots(figsize = (12, 10))

plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')

plt.xlabel('Age')
plt.ylabel('Mpg')
plt.show()

# %%
X = df[['displacement', 'horsepower' , 'weight']]
Y = df['mpg']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

linear_model = LinearRegression().fit(x_train, y_train)
print('Training Score: ', linear_model.score(x_train, y_train))

y_pred = linear_model.predict(x_test)
print('Testing Score: ', r2_score(y_test, y_pred))
# Out:
# Training Score:  0.7035377539762282
# Testing Score:  0.7142245045919886

# %%
#fig, ax = plt.subplots(figsize = (12, 10))
plt.figure(figsize = (20, 10))

plt.plot(y_pred, label = 'Predicted')
plt.plot(y_test.values, label = 'Actual')

plt.ylabel('Mpg')
plt.legend()
plt.show()

# %%
X = df[['displacement', 'horsepower' , 'weight', 'acceleration', 'cylinders']]
Y = df['mpg']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

linear_model = LinearRegression().fit(x_train, y_train)
print('Training Score: ', linear_model.score(x_train, y_train))

y_pred = linear_model.predict(x_test)
print('Testing Score: ', r2_score(y_test, y_pred))
# Out:
# Training Score:  0.7123124851493069
# Testing Score:  0.6844035069852349

# %%
plt.figure(figsize = (20, 10))

plt.plot(y_pred, label = 'Predicted')
plt.plot(y_test.values, label = 'Actual')

plt.ylabel('Mpg')
plt.legend()
plt.show()
