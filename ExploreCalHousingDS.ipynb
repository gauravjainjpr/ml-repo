# %% [markdown]
# # Import libraries

# %%
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load California Housing Dataset

# %%
from sklearn.datasets import fetch_california_housing

housing_dataset = pd.read_csv('./datasets/housing.csv')

df = housing_dataset

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7021     -118.10     33.98                34.0       1357.0           310.0
# 3589     -118.45     34.25                34.0       2094.0           380.0
# 12601    -121.48     38.53                37.0       1704.0           361.0
# 440      -122.30     37.88                46.0       1647.0           376.0
# 4390     -118.26     34.07                28.0        579.0           184.0
#
#        population  households  median_income  median_house_value  \
# 7021       1042.0       287.0         3.4083            156700.0
# 3589       1207.0       380.0         5.2801            212300.0
# 12601       902.0       356.0         1.9837             62300.0
# 440         854.0       355.0         2.9000            144800.0
# 4390        673.0       202.0         2.6250            187500.0
#
#       ocean_proximity
# 7021        <1H OCEAN
# 3589        <1H OCEAN
# 12601          INLAND
# 440          NEAR BAY
# 4390        <1H OCEAN

# %%
df.shape
# Out:
# (20640, 10)

# %%
# remove NAs

df = df.dropna()

# %%
df.shape
# Out:
# (20433, 10)

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563700
# 50%        435.000000   1166.000000    409.000000       3.536500
# 75%        647.000000   1722.000000    604.000000       4.744000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20433.000000
# mean        206864.413155
# std         115435.667099
# min          14999.000000
# 25%         119500.000000
# 50%         179700.000000
# 75%         264700.000000
# max         500001.000000

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %% [markdown]
# # Visual Analysis

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(df['total_rooms'],df['median_house_value'])

plt.xlabel('Total Rooms')
plt.ylabel('Median House Value')
# Out:
# Text(0, 0.5, 'Median House Value')

# %%
fig, ax = plt.subplots(figsize=(12,8))
plt.scatter(df['housing_median_age'],df['median_house_value'])

plt.xlabel('Median Age')
plt.ylabel('Median House Value')
# Out:
# Text(0, 0.5, 'Median House Value')

# %%
fig, ax = plt.subplots(figsize=(12,8))
plt.scatter(df['median_income']*10000,df['median_house_value'])

plt.xlabel('Median Income')
plt.ylabel('Median House Value')
# Out:
# Text(0, 0.5, 'Median House Value')

# %%
df_corr = df.iloc[:,0:9].corr()

df_corr
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# latitude                 -0.066983   -0.108997   -0.071774      -0.079626
# housing_median_age       -0.320451   -0.295787   -0.302768      -0.118278
# total_rooms               0.930380    0.857281    0.918992       0.197882
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
# population                0.877747    1.000000    0.907186       0.005087
# households                0.979728    0.907186    1.000000       0.013434
# median_income            -0.007723    0.005087    0.013434       1.000000
# median_house_value        0.049686   -0.025300    0.064894       0.688355
#
#                     median_house_value
# longitude                    -0.045398
# latitude                     -0.144638
# housing_median_age            0.106432
# total_rooms                   0.133294
# total_bedrooms                0.049686
# population                   -0.025300
# households                    0.064894
# median_income                 0.688355
# median_house_value            1.000000

# %%
fig, ax = plt.subplots(figsize = (10, 8))
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
df.loc[df['median_house_value']==500001].count()
# Out:
# longitude             958
# latitude              958
# housing_median_age    958
# total_rooms           958
# total_bedrooms        958
# population            958
# households            958
# median_income         958
# median_house_value    958
# ocean_proximity       958
# dtype: int64

# %%
df_new = df.drop(df.loc[df['median_house_value']==500001].index)

# %%
df_new.shape
# Out:
# (19475, 10)

# %%
df_new.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df_new = pd.get_dummies(df_new, columns = ['ocean_proximity'])

# %%
df_new.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 0                      False                   False                   False
# 1                      False                   False                   False
# 2                      False                   False                   False
# 3                      False                   False                   False
# 4                      False                   False                   False
#
#    ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN
# 0                      True                       False
# 1                      True                       False
# 2                      True                       False
# 3                      True                       False
# 4                      True                       False

# %%
X = df_new.drop('median_house_value', axis=1)
Y = df_new['median_house_value']

# %%
X.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
x_train.shape, x_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression().fit(x_train, y_train)

# %%
print('Training Score: ', linear_model.score(x_train, y_train))
# Out:
# Training Score:  0.6165752250374815

# %%
predictors = x_train.columns
predictors
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
coef = pd.Series(linear_model.coef_, predictors).sort_values()
print(coef)
# Out:
# ocean_proximity_INLAND        -69743.877321
# ocean_proximity_NEAR BAY      -37953.101026
# ocean_proximity_<1H OCEAN     -30279.399304
# ocean_proximity_NEAR OCEAN    -26193.467184
# longitude                     -24328.437392
# latitude                      -22389.597727
# population                       -29.565752
# total_rooms                       -7.171170
# households                        43.241160
# total_bedrooms                    89.531549
# housing_median_age               956.739857
# median_income                  38696.545054
# ocean_proximity_ISLAND        164169.844836
# dtype: float64

# %%
y_pred = linear_model.predict(x_test)

# %%
df_pred_actual = pd.DataFrame({'predicted': y_pred, 'actual': y_test})

df_pred_actual.head(10)
# Out:
#            predicted    actual
# 3340   149429.050197   83300.0
# 2147   120055.947169   67300.0
# 16286  102354.546775   73100.0
# 3570   263600.470261  229000.0
# 10195  212690.488434  184000.0
# 9989    94303.575620  143400.0
# 53     147774.490640  104200.0
# 1565   162383.059931  434700.0
# 16131  289059.962987  457800.0
# 13325   99879.461430   88300.0

# %%
from sklearn.metrics import r2_score

print("Testing Score: ", r2_score(y_test, y_pred))
# Out:
# Testing Score:  0.5971536191822278

# %%
fig, ax = plt.subplots(figsize = (10,8))

plt.scatter(y_test, y_pred)
plt.show()

# %%
df_pred_actual_sample = df_pred_actual.sample(100)
df_pred_actual_sample = df_pred_actual_sample.reset_index()

df_pred_actual_sample.head()
# Out:
#    index      predicted    actual
# 0  20239  220043.808768  166700.0
# 1   5542  307325.314059  432100.0
# 2  20587   42471.765985   70300.0
# 3   5878  249282.120516  293800.0
# 4    182  174128.348813  127900.0

# %%
plt.figure(figsize = (12,10))

plt.plot(df_pred_actual_sample['predicted'], label='Predicted')
plt.plot(df_pred_actual_sample['actual'], label='Actual')

plt.ylabel('median_house_value')
plt.legend()
plt.show()
